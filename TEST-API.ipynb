# %% [markdown]
# # Prueba de consumo de api

# %%
import requests
import json
import prettytable
headers = {'Content-type': 'application/json'}
data = json.dumps({"seriesid": ['CUUR0000SA0','SUUR0000SA0'],"startyear":"2018", "endyear":"2019"})
p = requests.post('https://api.bls.gov/publicAPI/v1/timeseries/data/', data=data, headers=headers)
json_data = json.loads(p.text)
for series in json_data['Results']['series']:
    x=prettytable.PrettyTable(["series id","year","period","value","footnotes"])
    seriesId = series['seriesID']
    for item in series['data']:
        year = item['year']
        period = item['period']
        value = item['value']
        footnotes=""
        for footnote in item['footnotes']:
            if footnote:
                footnotes = footnotes + footnote['text'] + ','
    
'if 'M01' <= period <= 'M12':'
            x.add_row([seriesId,year,period,value,footnotes[0:-1]])
    output = open(&quot;c:\\temp\\&quot; + seriesId + &quot;.txt&quot;,&quot;w&quot;)
    output.write (x.get_string())
    output.close()
# Out:
#   File "<tokenize>", line 22
#     output = open(&quot;c:\\temp\\&quot; + seriesId + &quot;.txt&quot;,&quot;w&quot;)
#     ^
# IndentationError: unindent does not match any outer indentation level

# %% [markdown]
# ## Llamada a la API y obtención de respuesta

# %%
import requests
import json

 
url = "https://api.bls.gov/publicAPI/v1/timeseries/data/"
 
 
data=json.dumps({"seriesid": ['CUUR0000SA0','SUUR0000SA0'],"startyear":"2017", "endyear":"2020"})
                    

headers = {'Content-type': 'application/json'}
 
response = requests.post(url, data=data, headers=headers)
#print first 4000 characters of response
print(response.text[:4000])
# Out:
# {"status":"REQUEST_SUCCEEDED","responseTime":176,"message":["No Data Available for Series CUUR0000SA0 Year: 2020","No Data Available for Series SUUR0000SA0 Year: 2020"],"Results":{
# "series":
# ...

# %%
data_recibida=response.text
preparseado=json.dumps(data_recibida, indent=4)
parseado=json.loads(data_recibida)
#with open('data.json', 'w') as f:
 #   json.dump(data_recibida, f)
#print(type(parseado['Results']['series']))
print(preparseado)
# Out:
# "{\"status\":\"REQUEST_SUCCEEDED\",\"responseTime\":176,\"message\":[\"No Data Available for Series CUUR0000SA0 Year: 2020\",\"No Data Available for Series SUUR0000SA0 Year: 2020\"],\"Results\":{\n\"series\":\n[{\"seriesID\":\"CUUR0000SA0\",\"data\":[{\"year\":\"2019\",\"period\":\"M12\",\"periodName\":\"December\",\"value\":\"256.974\",\"footnotes\":[{}]},{\"year\":\"2019\",\"period\":\"M11\",\"periodName\":\"November\",\"value\":\"257.208\",\"footnotes\":[{}]},{\"year\":\"2019\",\"period\":\"M10\",\"periodName\":\"October\",\"value\":\"257.346\",\"footnotes\":[{}]},{\"year\":\"2019\",\"period\":\"M09\",\"periodName\":\"September\",\"value\":\"256.759\",\"footnotes\":[{}]},{\"year\":\"2019\",\"period\":\"M08\",\"periodName\":\"August\",\"value\":\"256.558\",\"footnotes\":[{}]},{\"year\":\"2019\",\"period\":\"M07\",\"periodName\":\"July\",\"value\":\"256.571\",\"footnotes\":[{}]},{\"year\":\"2019\",\"period\":\"M06\",\"periodName\":\"June\",\"value\":\"256.143\",\"footnotes\":[{}]},{
# ...

# %% [markdown]
# # Limpieza de información

# %%
for i in range (0,len(parseado['Results']['series'])):    
    for elemento in parseado['Results']['series'][i]['data']:
        titulo=parseado['Results']['series'][i]['seriesID']
        year=elemento['year']
        periodName=elemento['periodName']
        value=elemento['value']
        print(titulo,year,periodName,value)
# Out:
# CUUR0000SA0 2019 December 256.974
# CUUR0000SA0 2019 November 257.208
# CUUR0000SA0 2019 October 257.346
# CUUR0000SA0 2019 September 256.759
# CUUR0000SA0 2019 August 256.558
# CUUR0000SA0 2019 July 256.571
# CUUR0000SA0 2019 June 256.143
# CUUR0000SA0 2019 May 256.092
# CUUR0000SA0 2019 April 255.548
# CUUR0000SA0 2019 March 254.202
# CUUR0000SA0 2019 February 252.776
# CUUR0000SA0 2019 January 251.712
# CUUR0000SA0 2018 December 251.233
# CUUR0000SA0 2018 November 252.038
# CUUR0000SA0 2018 October 252.885
# CUUR0000SA0 2018 September 252.439
# CUUR0000SA0 2018 August 252.146
# CUUR0000SA0 2018 July 252.006
# CUUR0000SA0 2018 June 251.989
# CUUR0000SA0 2018 May 251.588
# CUUR0000SA0 2018 April 250.546
# CUUR0000SA0 2018 March 249.554
# CUUR0000SA0 2018 February 248.991
# CUUR0000SA0 2018 January 247.867
# CUUR0000SA0 2017 December 246.524
# CUUR0000SA0 2017 November 246.669
# CUUR0000SA0 2017 October 246.663
# CUUR0000SA0 2017 September 246.819
# CUUR0000SA0 2017 August 245.519
# ...

# %%
preparseado=json.dumps(parseado, indent=4)
print (preparseado)
# Out:
# {
#     "status": "REQUEST_SUCCEEDED",
#     "responseTime": 127,
#     "message": [
#         "No Data Available for Series CUUR0000SA0 Year: 2020",
#         "No Data Available for Series SUUR0000SA0 Year: 2020"
#     ],
#     "Results": {
#         "series": [
#             {
#                 "seriesID": "CUUR0000SA0",
#                 "data": [
#                     {
#                         "year": "2019",
#                         "period": "M12",
#                         "periodName": "December",
#                         "value": "256.974",
#                         "footnotes": [
#                             {}
#                         ]
#                     },
#                     {
#                         "year": "2019",
#                         "period": "M11",
#                         "periodName": "November",
#                         "value": "257.208",
#                         "footnotes": [
#                             {}
#                         ]
# ...
